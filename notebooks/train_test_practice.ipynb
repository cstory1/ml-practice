# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
from  sklearn.model_selection import train_test_split

# %%
path = '../data/StudentPerformance.csv'

# %%
df= pd.read_csv(path)

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
ec = {'Yes': 1, 'No': 0}
df['Extracurricular Activities'] = df['Extracurricular Activities'].map(ec)

# %%
df.shape
# Out:
# (10000, 6)

# %%
X=df.drop(columns=['Performance Index'])

# %%
X.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
y=df['Performance Index']

# %%
y.head()
# Out:
# 0    91.0
# 1    65.0
# 2    45.0
# 3    36.0
# 4    66.0
# Name: Performance Index, dtype: float64

# %%
x_train, x_test, y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
x_train.shape
# Out:
# (8000, 5)

# %%
y_train.shape
# Out:
# (8000,)

# %%
from  sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()
linear_regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
linear_regression.predict(x_test)
# Out:
# array([41.47902964, 26.80356121, 34.25396502, ..., 46.55583459,
#        67.91222593, 59.16766817], shape=(2000,))

# %%
linear_regression.score(x_test, y_test)
# Out:
# 0.9886543202866286

# %%
x_test.head()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 937               1               67                           1            8
# 9355              5               41                           1            6
# 2293              2               59                           1            4
# 192               7               58                           0            4
# 8675              3               58                           1            8
#
#       Sample Question Papers Practiced
# 937                                  0
# 9355                                 7
# 2293                                 0
# 192                                  7
# 8675                                 8

# %%
x_test[0:1]
# Out:
#      Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 937              1               67                           1            8
#
#      Sample Question Papers Practiced
# 937                                 0

# %%
linear_regression.predict(x_test[0:1])
# Out:
# array([41.47902964])

# %%
y_test[0:1]
# Out:
# 937    38.0
# Name: Performance Index, dtype: float64

# %%
linear_regression.predict(x_test[1:4])
# Out:
# array([26.80356121, 34.25396502, 48.25683808])

# %%
y_test[1:4]
# Out:
# 9355    27.0
# 2293    30.0
# 192     49.0
# Name: Performance Index, dtype: float64

# %%
tree_x=df.drop(columns=['Extracurricular Activities'])
tree_x.head()
tree_y=df['Extracurricular Activities']
tree_y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Extracurricular Activities, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
dtree= DecisionTreeClassifier()
dtree.fit(tree_x, tree_y)
# Out:
# DecisionTreeClassifier()

# %%
from  sklearn import  tree
import matplotlib.pyplot as plt

# %%
tree.plot_tree(dtree)
# Out:
# [Text(0.32857142650412025, 0.9852941176470589, 'x[4] <= 22.5\ngini = 0.5\nsamples = 10000\nvalue = [5052, 4948]'),
#  Text(0.026035826979753974, 0.9558823529411765, 'x[4] <= 21.5\ngini = 0.481\nsamples = 365\nvalue = [218, 147]'),
#  Text(0.17730362674193711, 0.9705882352941178, 'True  '),
#  Text(0.013245411007175807, 0.9264705882352942, 'x[4] <= 15.5\ngini = 0.489\nsamples = 318\nvalue = [183, 135]'),
#  Text(0.0031394156842644797, 0.8970588235294118, 'x[3] <= 4.5\ngini = 0.42\nsamples = 60\nvalue = [42, 18]'),
#  Text(0.0020502306509482316, 0.8676470588235294, 'x[0] <= 2.5\ngini = 0.327\nsamples = 34\nvalue = [27, 7]'),
#  Text(0.0017939518195797027, 0.8382352941176471, 'x[1] <= 41.5\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(0.0015376729882111738, 0.8088235294117647, 'x[2] <= 7.5\ngini = 0.386\nsamples = 23\nvalue = [17, 6]'),
#  Text(0.0010251153254741158, 0.7794117647058824, 'x[2] <= 4.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
# ...
